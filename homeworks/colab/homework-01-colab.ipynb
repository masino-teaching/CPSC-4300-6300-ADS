# %% [markdown]
# <div class='heading'>
#     <div style='float:left;'><h1>CPSC 4300/6300: Applied Data Science</h1></div>
#      <img style="float: right; padding-right: 10px" width="100" src="https://raw.githubusercontent.com/bsethwalker/clemson-cs4300/main/images/clemson_paw.png"> </div>
#      </div>
#
# **Clemson University**<br>
# **Instructor(s):** Aaron Masino <br>
#
# ## Homework 1: Introduction to Python and its Numerical Stack
# This homework is intended to assess your knowledge of core elements of the Python programming language and Numpy, a Python library for efficiently performing numerical computations as introduced during the in-class lectures and labs. In this assignment, you are asked to complete exercises that will assess your knowledge of Python data structures, Python control flow operators, Python functions, and numpy array manipulations. You may wish to refer to the course lectures and labs while completing this assignment. For complete information, you may reference the Python documentation [here](https://www.python.org/) and the Numpy documentation [here](hhttps://numpy.org/).

# %%
import numpy as np

# %% [markdown]
# ### Excercise 1 (1 point)
# In the code cell below, create a tuple called `tup` that contains the following elements:
#
# - The first element is an integer of your choice
# - The second element is a float of your choice
# - The third element is the sum of the first two elements
# - The fourth element is the difference of the first two elements
# - The fifth element is the first element multiplied by the second element
#
# Display the output of `tup`.

# %%
######## YOUR CODE HERE ########

# %% [markdown]
# ### Exercise 2 (1 point)
# In the code cell below, use the appropriate Python operator to return the integer remainder when diving 197 by 42.

# %%
######## YOUR CODE HERE ########

# %% [markdown]
# ### Exercise 3 (1 point)
# In the code cell below, the code to sample a random number between 0 and 1 and assign the variable `r` is created for you using numpy. Use the appropriate control flow operator to print `0` if `r<0.5` and to print `1` otherwise.

# %%
np.random.seed(654321) # Seed the random number generator to get reproducible results
r = np.random.rand(1)

######## YOUR CODE HERE ########

# %% [markdown]
# ### Exercise 4 (1 point)
# In the code cell below, print the number of unique items in the list `l`. Hint: Review lab 2 information on _sets_ and _lists_.

# %%
l = [1,1,1,4,4,4,1,2,2,4,5,6,98,6,534,44,2,43,7,222,4453,1,0,2,3,4,2,6,74,445,32,565,34,4,72]

######## YOUR CODE HERE ########

# %% [markdown]
# ### Excercise 5 (1 point)
# In the code cell below, build a list that contains every prime number between 1 and 100 - remember 1 is _not_ prime. You may use for loops and conditional if statements or list comprehension. Display the list. Hint: A number `k>=2` is prime `k` divided by `n` has a non-zero remainder for all values of `n` in `range(2,k)`.

# %%
######## YOUR CODE HERE ########
# list comprehension solution

# %% [markdown]
# ### Excercise 6 (1 point)
#
# In the code cell below, write a function called `isprime()` that takes in a positive integer $N$, and determines whether or not it is prime.  Return `True` if it's prime and return `False` if it isn't. Then, using list comprehension and `isprime()`, create a list `myprimes` that contains all the prime numbers less than 100.  Display the list.

# %%
######## YOUR CODE HERE ########

# %% [markdown]
# ### Exercise 7 (1 point)
# The `max()` method is member of the np.array class and can be used to find the maximum value in a 1-D vector. For example:
# ```
# l = np.array([1,2,3])
# l.max()
# ```
# will yield the value 3.
# In the code cell below, the dictionary contains a `key:value` pairs where each value is an array. Use the appropriate control flow operator to iterate over the dictionary values and the `max` function to print the maximum for each item in the dictionary.

# %%
np.random.seed(654321) # Seed the random number generator to get reproducible results
d = {'l1': np.array([1,2,3,4,5]),
    'l2': np.array([-1, 0, -4]),
    'l3': np.array([1, 3, 5, 7, 9, 11]),
    'l4': np.random.rand(10)}

######## YOUR CODE HERE ########

# %% [markdown]
# ### Exercise 8 (1 point)
# In the code cell below, multiply every element in the array, `l`, by 100 and print ONLY items 46 through 49 from the array (remember Python container indices, including np.array are 0 based). The output should show 4 items.

# %%
np.random.seed(654321) # Seed the random number generator to get reproducible results
l = np.random.rand(100)

######## YOUR CODE HERE ########

# %% [markdown]
# ### Exercise 9 (2 points)
# In the code cell below, create a numpy array with 10 entries all equal to 3.14 and another one with 10 entries equal to -3.14. Then add the arrays and print the results.

# %%
######## YOUR CODE HERE ########
